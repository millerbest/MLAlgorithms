# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("Social_Network_Ads.csv")

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %% [markdown]
# Getting information about our dataset

# %%
#for checking the unique values present in our Purchased columns 
print(pd.unique(df.Purchased))

print("shape = {0}".format(df.shape))

print("column names = {0}".format(df.columns))

#getting the count of purchased or not
count = df['Purchased'].value_counts()
#print(count)

print("# of people purchased = {0} \n# of people didn't purchased = {1}".format(count[1],count[0]))
# Out:
# [0 1]
# shape = (400, 5)
# column names = Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')
# # of people purchased = 143
# # of people didn't purchased = 257

# %%
Age = df['Age'].unique()
count = df['Age'].value_counts()
# Out:
# 35    32
# 37    20
# 41    16
# 42    16
# 26    16
# 39    15
# 40    15
# 47    14
# 48    14
# 38    13
# 27    13
# 28    12
# 46    12
# 36    12
# 31    11
# 30    11
# 29    10
# 49    10
# 32     9
# 33     9
# 24     9
# 20     7
# 19     7
# 60     7
# 59     7
# 45     7
# 25     6
# 34     6
# 58     6
# 52     6
# 23     6
# 57     5
# 22     5
# 18     5
# 53     5
# 21     4
# 50     4
# 54     4
# 55     3
# 43     3
# 56     3
# 51     3
# 44     2
# Name: Age, dtype: int64

# %%
df.hist()
plt.show()

# %%
#plt.scatter([0,1],df['Purchased'].value_counts())
#plt.show()

# %%
#we grouped our dataset on our result variable ='Purchased'

grouped = df.groupby('Purchased')
#for result,group in grouped:
    #print (result)
    #print (group)

g0 = grouped.get_group(0)
g1 = grouped.get_group(1)

# %%
#Grouping our dataset on the  column variable = 'Age'
age_grouped = df.groupby('Age')
for age,group in age_grouped:
    print("age = {0}".format(age))
    print(group)
    print("\n")
# Out:
# age = 18
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 14   15628972    Male   18            82000          0
# 51   15764195  Female   18            44000          0
# 76   15746737    Male   18            52000          0
# 141  15666141  Female   18            68000          0
# 165  15578738  Female   18            86000          0
#
#
# age = 19
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 4    15804002    Male   19            76000          0
# 104  15672091  Female   19            21000          0
# 139  15741094    Male   19            25000          0
# 140  15807909    Male   19            85000          0
# 191  15662067  Female   19            26000          0
# 193  15662901    Male   19            70000          0
#
#
# age = 20
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 12   15746139    Male   20            86000          0
# ...

# %%
#Plotting the data between 'EstimatedSalary' and 'Purchased'
plt.scatter(df['EstimatedSalary'],df['Purchased'])
#Here we can see that people with higher have purchased the item more than people at lower salary

# %%
#grouping the data by column 'Gender'
print(df['Gender'].value_counts())  
group_gender = df.groupby('Gender')
group_gender['Purchased'].value_counts()
# Out:
# Female    204
# Male      196
# Name: Gender, dtype: int64
# Gender  Purchased
# Female  0            127
#         1             77
# Male    0            130
#         1             66
# Name: Purchased, dtype: int64

# %%
#turning the Gender column into numerical categories and we will
